# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import numpy as np

import matplotlib.pyplot as plt

def weights_init(m):
    if type(m) == nn.Linear:
        m.weight.data.normal_(0.0, 1e-3)
        m.bias.data.fill_(0.)

def update_lr(optimizer, lr):
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

#--------------------------------
# Device configuration
#--------------------------------
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device: %s'%device)

#--------------------------------
# Hyper-parameters
#--------------------------------
input_size = 3
num_classes = 10
hidden_size = [128, 512, 512, 512, 512]
num_epochs = 50
batch_size = 200
learning_rate = 2e-3
learning_rate_decay = 0.95
reg=0.001
num_training= 49000
num_validation =1000
norm_layer = None #norm_layer = 'BN'
print(hidden_size)



#-------------------------------------------------
# Load the CIFAR-10 dataset
#-------------------------------------------------
#################################################################################
# TODO: Q3.a Choose the right data augmentation transforms with the right       #
# hyper-parameters and put them in the data_aug_transforms variable             #
#################################################################################
data_aug_transforms = []
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****



# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
norm_transform = transforms.Compose(data_aug_transforms+[transforms.ToTensor(),
                                     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                                     ])
test_transform = transforms.Compose([transforms.ToTensor(),
                                     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                                     ])
cifar_dataset = torchvision.datasets.CIFAR10(root='datasets/',
                                           train=True,
                                           transform=norm_transform,
                                           download=True)

test_dataset = torchvision.datasets.CIFAR10(root='datasets/',
                                          train=False,
                                          transform=test_transform
                                          )

#-------------------------------------------------
# Prepare the training and validation splits
#-------------------------------------------------
mask = list(range(num_training))
train_dataset = torch.utils.data.Subset(cifar_dataset, mask)
mask = list(range(num_training, num_training + num_validation))
val_dataset = torch.utils.data.Subset(cifar_dataset, mask)

#-------------------------------------------------
# Data loader
#-------------------------------------------------
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)

val_loader = torch.utils.data.DataLoader(dataset=val_dataset,
                                           batch_size=batch_size,
                                           shuffle=False)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False)


#-------------------------------------------------
# Convolutional neural network (Q1.a and Q2.a)
# Set norm_layer for different networks whether using batch normalization
#-------------------------------------------------
class ConvNet(nn.Module):
    def __init__(self, input_size, hidden_layers, num_classes, norm_layer=None):
        super(ConvNet, self).__init__()
        #################################################################################
        # TODO: Initialize the modules required to implement the convolutional layer    #
        # described in the exercise.                                                    #
        # For Q1.a make use of conv2d and relu layers from the torch.nn module.         #
        # For Q2.a make use of BatchNorm2d layer from the torch.nn module.              #
        # For Q3.b Use Dropout layer from the torch.nn module.                          #
        #################################################################################
        layers = []
        # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        
        self.input_size = input_size
        self.hidden_layers = hidden_layers
        self.num_classes = num_classes
        self.norm_layer = norm_layer
        
        for i in range(len(hidden_layers)):
            if i == 0:
                layers.append(nn.Conv2d(self.input_size,self.hidden_layers[i],kernel_size = 3,stride = 1,padding = 1))
                layers.append(nn.BatchNorm2d(self.hidden_layers[i]))
                layers.append(nn.MaxPool2d(2, 2))
                layers.append(nn.ReLU())
            else:
                layers.append(nn.Conv2d(self.hidden_layers[i-1],self.hidden_layers[i],kernel_size = 3,stride = 1,padding = 1))
                layers.append(nn.BatchNorm2d(self.hidden_layers[i]))
                layers.append(nn.MaxPool2d(2, 2))
                layers.append(nn.ReLU())
        self.layers = nn.Sequential(*layers)
        self.classifier = nn.Sequential(nn.Linear(self.hidden_layers[i],num_classes))
        # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

    def forward(self, x):
        #################################################################################
        # TODO: Implement the forward pass computations                                 #
        #################################################################################
        # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        x = self.layers(x)
        x = x.view(batch_size,self.hidden_layers[-1])
        out = self.classifier(x)
        # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        return out

#-------------------------------------------------
# Calculate the model size (Q1.b)
# if disp is true, print the model parameters, otherwise, only return the number of parameters.
#-------------------------------------------------
def PrintModelSize(model, disp=True):
    #################################################################################
    # TODO: Implement the function to count the number of trainable parameters in   #
    # the input model. This useful to track the capacity of the model you are       #
    # training                                                                      #
    #################################################################################
    # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    model_sz=0
    for p in list(model.parameters()):
        nn=1
        for s in list(p.size()):
            nn = nn*s
        model_sz += nn
    print('model_sz: ', model_sz)
    # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    return model_sz

#-------------------------------------------------
# Calculate the model size (Q1.c)
# visualize the convolution filters of the first convolution layer of the input model
#-------------------------------------------------
def VisualizeFilter(model):
    #################################################################################
    # TODO: Implement the functiont to visualize the weights in the first conv layer#
    # in the model. Visualize them as a single image of stacked filters.            #
    # You can use matlplotlib.imshow to visualize an image in python                #
    #################################################################################
    # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    img = torchvision.utils.make_grid(model.layers[0].weight.detach().cpu())     # unnormalize
    fig = plt.figure(figsize=(15, 15))
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (2, 1, 0)))
    plt.show()
    #pass
    # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

#======================================================================================
# Q1.a: Implementing convolutional neural net in PyTorch
#======================================================================================
# In this question we will implement a convolutional neural networks using the PyTorch
# library.  Please complete the code for the ConvNet class evaluating the model
#--------------------------------------------------------------------------------------
model = ConvNet(input_size, hidden_size, num_classes, norm_layer=norm_layer).to(device)
# Q2.a - Initialize the model with correct batch norm layer

model.apply(weights_init)
# Print the model
print(model)
# Print model size
#======================================================================================
# Q1.b: Implementing the function to count the number of trainable parameters in the model
#======================================================================================
PrintModelSize(model)
#======================================================================================
# Q1.a: Implementing the function to visualize the filters in the first conv layers.
# Visualize the filters before training
#======================================================================================
VisualizeFilter(model)


# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=reg)

# Train the model
lr = learning_rate
total_step = len(train_loader)
loss_train = []
loss_val = []
best_accuracy = None
accuracy_val = []
best_model = type(model)(input_size, hidden_size, num_classes, norm_layer=norm_layer) # get a new instance
#best_model = ConvNet(input_size, hidden_size, num_classes, norm_layer=norm_layer)
for epoch in range(num_epochs):

    model.train()

    loss_iter = 0
    for i, (images, labels) in enumerate(train_loader):
        # Move tensors to the configured device
        images = images.to(device)
        labels = labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        loss_iter += loss.item()
        
        if (i+1) % 100 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
            
    loss_train.append(loss_iter/(len(train_loader)*batch_size))

    
    # Code to update the lr
    lr *= learning_rate_decay
    update_lr(optimizer, lr)
    
        
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        loss_iter = 0
        for images, labels in val_loader:
            images = images.to(device)
            labels = labels.to(device)
            
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            
            loss = criterion(outputs, labels)
            loss_iter += loss.item()
        
        loss_val.append(loss_iter/(len(val_loader)*batch_size))

        accuracy = 100 * correct / total
        accuracy_val.append(accuracy)
        print('Validation accuracy is: {} %'.format(accuracy))
    

# Test the model
# In test phase, we don't need to compute gradients (for memory efficiency)
model.eval()



plt.figure(2)
plt.plot(loss_train, 'r', label='Train loss')
plt.plot(loss_val, 'g', label='Val loss')
plt.legend()
plt.show()

plt.figure(3)
plt.plot(accuracy_val, 'r', label='Val accuracy')
plt.legend()
plt.show()


#Compute accuracy on the test set
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        if total == 1000:
            break

    print('Accuracy of the network on the {} test images: {} %'.format(total, 100 * correct / total))

    #-------------------------------------------------
# Convolutional neural network (Q1.a and Q2.a)
# Set norm_layer for different networks whether using batch normalization
#-------------------------------------------------
class ConvNet(nn.Module):
    def __init__(self, input_size, hidden_layers, num_classes, norm_layer=None):
        super(ConvNet, self).__init__()
        #################################################################################
        # TODO: Initialize the modules required to implement the convolutional layer    #
        # described in the exercise.                                                    #
        # For Q1.a make use of conv2d and relu layers from the torch.nn module.         #
        # For Q2.a make use of BatchNorm2d layer from the torch.nn module.              #
        # For Q3.b Use Dropout layer from the torch.nn module.                          #
        #################################################################################
        layers = []
        # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        
        self.input_size = input_size
        self.hidden_layers = hidden_layers
        self.num_classes = num_classes
        self.norm_layer = norm_layer
        
        for i in range(len(hidden_layers)):
            if i == 0:
                layers.append(nn.Conv2d(self.input_size,self.hidden_layers[i],kernel_size = 3,stride = 1,padding = 1))
               # layers.append(nn.BatchNorm2d(self.hidden_layers[i]))
                layers.append(nn.MaxPool2d(2, 2))
                layers.append(nn.ReLU())
            else:
                layers.append(nn.Conv2d(self.hidden_layers[i-1],self.hidden_layers[i],kernel_size = 3,stride = 1,padding = 1))
              #  layers.append(nn.BatchNorm2d(self.hidden_layers[i]))
                layers.append(nn.MaxPool2d(2, 2))
                layers.append(nn.ReLU())
        self.layers = nn.Sequential(*layers)
        self.classifier = nn.Sequential(nn.Linear(self.hidden_layers[i],num_classes))
        # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

    def forward(self, x):
        #################################################################################
        # TODO: Implement the forward pass computations                                 #
        #################################################################################
        # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        x = self.layers(x)
        x = x.view(batch_size,self.hidden_layers[-1])
        out = self.classifier(x)
        # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        return out

#-------------------------------------------------
# Calculate the model size (Q1.b)
# if disp is true, print the model parameters, otherwise, only return the number of parameters.
#-------------------------------------------------
def PrintModelSize(model, disp=True):
    #################################################################################
    # TODO: Implement the function to count the number of trainable parameters in   #
    # the input model. This useful to track the capacity of the model you are       #
    # training                                                                      #
    #################################################################################
    # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    model_sz=0
    for p in list(model.parameters()):
        nn=1
        for s in list(p.size()):
            nn = nn*s
        model_sz += nn
    print('model_sz: ', model_sz)
    # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    return model_sz

#-------------------------------------------------
# Calculate the model size (Q1.c)
# visualize the convolution filters of the first convolution layer of the input model
#-------------------------------------------------
def VisualizeFilter(model):
    #################################################################################
    # TODO: Implement the functiont to visualize the weights in the first conv layer#
    # in the model. Visualize them as a single image of stacked filters.            #
    # You can use matlplotlib.imshow to visualize an image in python                #
    #################################################################################
    # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    img = torchvision.utils.make_grid(model.layers[0].weight.detach().cpu())     # unnormalize
    fig = plt.figure(figsize=(15, 15))
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (2, 1, 0)))
    plt.show()
    #pass
    # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

#======================================================================================
# Q1.a: Implementing convolutional neural net in PyTorch
#======================================================================================
# In this question we will implement a convolutional neural networks using the PyTorch
# library.  Please complete the code for the ConvNet class evaluating the model
#--------------------------------------------------------------------------------------
model = ConvNet(input_size, hidden_size, num_classes, norm_layer=norm_layer).to(device)
# Q2.a - Initialize the model with correct batch norm layer

model.apply(weights_init)
# Print the model
print(model)
# Print model size
#======================================================================================
# Q1.b: Implementing the function to count the number of trainable parameters in the model
#======================================================================================
PrintModelSize(model)
#======================================================================================
# Q1.a: Implementing the function to visualize the filters in the first conv layers.
# Visualize the filters before training
#======================================================================================
VisualizeFilter(model)


# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=reg)

# Train the model
lr = learning_rate
total_step = len(train_loader)
loss_train = []
loss_val = []
best_accuracy = None
accuracy_val = []
best_model = type(model)(input_size, hidden_size, num_classes, norm_layer=norm_layer) # get a new instance
#best_model = ConvNet(input_size, hidden_size, num_classes, norm_layer=norm_layer)
for epoch in range(num_epochs):

    model.train()

    loss_iter = 0
    for i, (images, labels) in enumerate(train_loader):
        # Move tensors to the configured device
        images = images.to(device)
        labels = labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        loss_iter += loss.item()
        
        if (i+1) % 100 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
            
    loss_train.append(loss_iter/(len(train_loader)*batch_size))

    
    # Code to update the lr
    lr *= learning_rate_decay
    update_lr(optimizer, lr)
    
        
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        loss_iter = 0
        for images, labels in val_loader:
            images = images.to(device)
            labels = labels.to(device)
            
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            
            loss = criterion(outputs, labels)
            loss_iter += loss.item()
        
        loss_val.append(loss_iter/(len(val_loader)*batch_size))

        accuracy = 100 * correct / total
        accuracy_val.append(accuracy)
        print('Validation accuracy is: {} %'.format(accuracy))
    

# Test the model
# In test phase, we don't need to compute gradients (for memory efficiency)
model.eval()



plt.figure(2)
plt.plot(loss_train, 'r', label='Train loss')
plt.plot(loss_val, 'g', label='Val loss')
plt.legend()
plt.show()

plt.figure(3)
plt.plot(accuracy_val, 'r', label='Val accuracy')
plt.legend()
plt.show()


#Compute accuracy on the test set
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        if total == 1000:
            break

    print('Accuracy of the network on the {} test images: {} %'.format(total, 100 * correct / total))
# Out:
# Using device: cuda
# [128, 512, 512, 512, 512]
# Files already downloaded and verified
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ConvNet(
#   (layers): Sequential(
#     (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): ReLU()
#     (4): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): ReLU()
#     (8): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): ReLU()
#     (12): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): ReLU()
#     (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): ReLU()
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=512, out_features=10, bias=True)
#   )
# )
# model_sz:  7682826
# Epoch [1/50], Step [100/245], Loss: 1.2593
# Epoch [1/50], Step [200/245], Loss: 1.0070
# Validation accuracy is: 49.5 %
# Epoch [2/50], Step [100/245], Loss: 0.9378
# Epoch [2/50], Step [200/245], Loss: 0.9725
# Validation accuracy is: 60.9 %
# Epoch [3/50], Step [100/245], Loss: 0.9438
# Epoch [3/50], Step [200/245], Loss: 0.8207
# Validation accuracy is: 67.8 %
# Epoch [4/50], Step [100/245], Loss: 0.6864
# Epoch [4/50], Step [200/245], Loss: 0.5258
# Validation accuracy is: 69.6 %
# Epoch [5/50], Step [100/245], Loss: 0.5099
# Epoch [5/50], Step [200/245], Loss: 0.4434
# Validation accuracy is: 74.8 %
# Epoch [6/50], Step [100/245], Loss: 0.5449
# Epoch [6/50], Step [200/245], Loss: 0.5637
# Validation accuracy is: 78.7 %
# Epoch [7/50], Step [100/245], Loss: 0.5121
# Epoch [7/50], Step [200/245], Loss: 0.4743
# Validation accuracy is: 81.2 %
# Epoch [8/50], Step [100/245], Loss: 0.4604
# Epoch [8/50], Step [200/245], Loss: 0.3606
# Validation accuracy is: 79.5 %
# Epoch [9/50], Step [100/245], Loss: 0.2579
# Epoch [9/50], Step [200/245], Loss: 0.3774
# Validation accuracy is: 76.6 %
# Epoch [10/50], Step [100/245], Loss: 0.3921
# Epoch [10/50], Step [200/245], Loss: 0.2995
# Validation accuracy is: 80.1 %
# Epoch [11/50], Step [100/245], Loss: 0.2445
# Epoch [11/50], Step [200/245], Loss: 0.1709
# Validation accuracy is: 80.6 %
# Epoch [12/50], Step [100/245], Loss: 0.2064
# Epoch [12/50], Step [200/245], Loss: 0.2033
# Validation accuracy is: 80.9 %
# Epoch [13/50], Step [100/245], Loss: 0.1287
# Epoch [13/50], Step [200/245], Loss: 0.1610
# Validation accuracy is: 79.5 %
# Epoch [14/50], Step [100/245], Loss: 0.1198
# Epoch [14/50], Step [200/245], Loss: 0.1534
# Validation accuracy is: 80.6 %
# Epoch [15/50], Step [100/245], Loss: 0.0650
# Epoch [15/50], Step [200/245], Loss: 0.1940
# Validation accuracy is: 81.6 %
# Epoch [16/50], Step [100/245], Loss: 0.0977
# Epoch [16/50], Step [200/245], Loss: 0.0760
# Validation accuracy is: 81.4 %
# Epoch [17/50], Step [100/245], Loss: 0.0607
# Epoch [17/50], Step [200/245], Loss: 0.0945
# Validation accuracy is: 82.4 %
# Epoch [18/50], Step [100/245], Loss: 0.0534
# Epoch [18/50], Step [200/245], Loss: 0.0672
# Validation accuracy is: 81.1 %
# Epoch [19/50], Step [100/245], Loss: 0.0261
# Epoch [19/50], Step [200/245], Loss: 0.0707
# Validation accuracy is: 82.1 %
# Epoch [20/50], Step [100/245], Loss: 0.0320
# Epoch [20/50], Step [200/245], Loss: 0.0819
# Validation accuracy is: 81.2 %
# Epoch [21/50], Step [100/245], Loss: 0.0405
# Epoch [21/50], Step [200/245], Loss: 0.0496
# Validation accuracy is: 82.5 %
# Epoch [22/50], Step [100/245], Loss: 0.0400
# Epoch [22/50], Step [200/245], Loss: 0.0313
# Validation accuracy is: 82.1 %
# Epoch [23/50], Step [100/245], Loss: 0.0223
# Epoch [23/50], Step [200/245], Loss: 0.0315
# Validation accuracy is: 82.4 %
# Epoch [24/50], Step [100/245], Loss: 0.0158
# Epoch [24/50], Step [200/245], Loss: 0.0149
# Validation accuracy is: 82.3 %
# Epoch [25/50], Step [100/245], Loss: 0.0196
# Epoch [25/50], Step [200/245], Loss: 0.0285
# Validation accuracy is: 80.6 %
# Epoch [26/50], Step [100/245], Loss: 0.0244
# Epoch [26/50], Step [200/245], Loss: 0.0506
# Validation accuracy is: 83.5 %
# Epoch [27/50], Step [100/245], Loss: 0.0327
# Epoch [27/50], Step [200/245], Loss: 0.0714
# Validation accuracy is: 80.6 %
# Epoch [28/50], Step [100/245], Loss: 0.0232
# Epoch [28/50], Step [200/245], Loss: 0.0254
# Validation accuracy is: 82.2 %
# Epoch [29/50], Step [100/245], Loss: 0.0127
# Epoch [29/50], Step [200/245], Loss: 0.0183
# Validation accuracy is: 83.8 %
# Epoch [30/50], Step [100/245], Loss: 0.0162
# Epoch [30/50], Step [200/245], Loss: 0.0096
# Validation accuracy is: 84.2 %
# Epoch [31/50], Step [100/245], Loss: 0.0097
# Epoch [31/50], Step [200/245], Loss: 0.0049
# Validation accuracy is: 83.4 %
# Epoch [32/50], Step [100/245], Loss: 0.0021
# Epoch [32/50], Step [200/245], Loss: 0.0066
# Validation accuracy is: 84.4 %
# Epoch [33/50], Step [100/245], Loss: 0.0030
# Epoch [33/50], Step [200/245], Loss: 0.0040
# Validation accuracy is: 83.7 %
# Epoch [34/50], Step [100/245], Loss: 0.0029
# Epoch [34/50], Step [200/245], Loss: 0.0037
# Validation accuracy is: 83.6 %
# Epoch [35/50], Step [100/245], Loss: 0.0041
# Epoch [35/50], Step [200/245], Loss: 0.0038
# Validation accuracy is: 84.1 %
# Epoch [36/50], Step [100/245], Loss: 0.0029
# Epoch [36/50], Step [200/245], Loss: 0.0043
# Validation accuracy is: 83.7 %
# Epoch [37/50], Step [100/245], Loss: 0.0035
# Epoch [37/50], Step [200/245], Loss: 0.0045
# Validation accuracy is: 83.8 %
# Epoch [38/50], Step [100/245], Loss: 0.0088
# Epoch [38/50], Step [200/245], Loss: 0.1727
# Validation accuracy is: 74.6 %
# Epoch [39/50], Step [100/245], Loss: 0.1309
# Epoch [39/50], Step [200/245], Loss: 0.1157
# Validation accuracy is: 81.8 %
# Epoch [40/50], Step [100/245], Loss: 0.0312
# Epoch [40/50], Step [200/245], Loss: 0.0450
# Validation accuracy is: 82.3 %
# Epoch [41/50], Step [100/245], Loss: 0.0123
# Epoch [41/50], Step [200/245], Loss: 0.0088
# Validation accuracy is: 83.1 %
# Epoch [42/50], Step [100/245], Loss: 0.0043
# Epoch [42/50], Step [200/245], Loss: 0.0036
# Validation accuracy is: 83.5 %
# Epoch [43/50], Step [100/245], Loss: 0.0043
# Epoch [43/50], Step [200/245], Loss: 0.0049
# Validation accuracy is: 83.1 %
# Epoch [44/50], Step [100/245], Loss: 0.0037
# Epoch [44/50], Step [200/245], Loss: 0.0027
# Validation accuracy is: 83.5 %
# Epoch [45/50], Step [100/245], Loss: 0.0024
# Epoch [45/50], Step [200/245], Loss: 0.0034
# Validation accuracy is: 83.1 %
# Epoch [46/50], Step [100/245], Loss: 0.0026
# Epoch [46/50], Step [200/245], Loss: 0.0032
# Validation accuracy is: 83.4 %
# Epoch [47/50], Step [100/245], Loss: 0.0033
# Epoch [47/50], Step [200/245], Loss: 0.0046
# Validation accuracy is: 83.3 %
# Epoch [48/50], Step [100/245], Loss: 0.0025
# Epoch [48/50], Step [200/245], Loss: 0.0038
# Validation accuracy is: 83.7 %
# Epoch [49/50], Step [100/245], Loss: 0.0029
# Epoch [49/50], Step [200/245], Loss: 0.0034
# Validation accuracy is: 83.2 %
# Epoch [50/50], Step [100/245], Loss: 0.0028
# Epoch [50/50], Step [200/245], Loss: 0.0030
# Validation accuracy is: 83.3 %
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Accuracy of the network on the 1000 test images: 82.0 %
# ConvNet(
#   (layers): Sequential(
#     (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#     (3): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): ReLU()
#     (6): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): ReLU()
#     (9): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): ReLU()
#     (12): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): ReLU()
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=512, out_features=10, bias=True)
#   )
# )
# model_sz:  7678474
# Epoch [1/50], Step [100/245], Loss: 1.5999
# Epoch [1/50], Step [200/245], Loss: 1.3832
# Validation accuracy is: 49.4 %
# Epoch [2/50], Step [100/245], Loss: 1.1132
# Epoch [2/50], Step [200/245], Loss: 1.1635
# Validation accuracy is: 63.1 %
# Epoch [3/50], Step [100/245], Loss: 0.9239
# Epoch [3/50], Step [200/245], Loss: 0.8807
# Validation accuracy is: 65.2 %
# Epoch [4/50], Step [100/245], Loss: 0.8922
# Epoch [4/50], Step [200/245], Loss: 0.9240
# Validation accuracy is: 74.1 %
# Epoch [5/50], Step [100/245], Loss: 0.6501
# Epoch [5/50], Step [200/245], Loss: 0.6728
# Validation accuracy is: 75.9 %
# Epoch [6/50], Step [100/245], Loss: 0.5674
# Epoch [6/50], Step [200/245], Loss: 0.7634
# Validation accuracy is: 76.8 %
# Epoch [7/50], Step [100/245], Loss: 0.5400
# Epoch [7/50], Step [200/245], Loss: 0.6697
# Validation accuracy is: 78.6 %
# Epoch [8/50], Step [100/245], Loss: 0.4287
# Epoch [8/50], Step [200/245], Loss: 0.5887
# Validation accuracy is: 77.0 %
# Epoch [9/50], Step [100/245], Loss: 0.4006
# Epoch [9/50], Step [200/245], Loss: 0.4825
# Validation accuracy is: 78.4 %
# Epoch [10/50], Step [100/245], Loss: 0.4700
# Epoch [10/50], Step [200/245], Loss: 0.4437
# Validation accuracy is: 79.8 %
# Epoch [11/50], Step [100/245], Loss: 0.3264
# Epoch [11/50], Step [200/245], Loss: 0.3470
# Validation accuracy is: 79.2 %
# Epoch [12/50], Step [100/245], Loss: 0.2132
# Epoch [12/50], Step [200/245], Loss: 0.3714
# Validation accuracy is: 79.6 %
# Epoch [13/50], Step [100/245], Loss: 0.2434
# Epoch [13/50], Step [200/245], Loss: 0.2908
# Validation accuracy is: 79.7 %
# Epoch [14/50], Step [100/245], Loss: 0.2575
# Epoch [14/50], Step [200/245], Loss: 0.2442
# Validation accuracy is: 78.7 %
# Epoch [15/50], Step [100/245], Loss: 0.1281
# Epoch [15/50], Step [200/245], Loss: 0.2515
# Validation accuracy is: 80.4 %
# Epoch [16/50], Step [100/245], Loss: 0.1034
# Epoch [16/50], Step [200/245], Loss: 0.2208
# Validation accuracy is: 80.4 %
# Epoch [17/50], Step [100/245], Loss: 0.1644
# Epoch [17/50], Step [200/245], Loss: 0.1204
# Validation accuracy is: 77.6 %
# Epoch [18/50], Step [100/245], Loss: 0.1373
# Epoch [18/50], Step [200/245], Loss: 0.1283
# Validation accuracy is: 80.6 %
# Epoch [19/50], Step [100/245], Loss: 0.0963
# Epoch [19/50], Step [200/245], Loss: 0.1359
# Validation accuracy is: 79.4 %
# Epoch [20/50], Step [100/245], Loss: 0.0629
# Epoch [20/50], Step [200/245], Loss: 0.1247
# Validation accuracy is: 80.4 %
# Epoch [21/50], Step [100/245], Loss: 0.0852
# Epoch [21/50], Step [200/245], Loss: 0.0772
# Validation accuracy is: 80.1 %
# Epoch [22/50], Step [100/245], Loss: 0.0352
# Epoch [22/50], Step [200/245], Loss: 0.0605
# Validation accuracy is: 80.7 %
# Epoch [23/50], Step [100/245], Loss: 0.0311
# Epoch [23/50], Step [200/245], Loss: 0.0404
# Validation accuracy is: 80.9 %
# Epoch [24/50], Step [100/245], Loss: 0.0372
# Epoch [24/50], Step [200/245], Loss: 0.0694
# Validation accuracy is: 80.3 %
# Epoch [25/50], Step [100/245], Loss: 0.0426
# Epoch [25/50], Step [200/245], Loss: 0.0506
# Validation accuracy is: 79.9 %
# Epoch [26/50], Step [100/245], Loss: 0.0396
# Epoch [26/50], Step [200/245], Loss: 0.0540
# Validation accuracy is: 79.6 %
# Epoch [27/50], Step [100/245], Loss: 0.0398
# Epoch [27/50], Step [200/245], Loss: 0.0330
# Validation accuracy is: 80.3 %
# Epoch [28/50], Step [100/245], Loss: 0.0270
# Epoch [28/50], Step [200/245], Loss: 0.0529
# Validation accuracy is: 80.2 %
# Epoch [29/50], Step [100/245], Loss: 0.0372
# Epoch [29/50], Step [200/245], Loss: 0.0336
# Validation accuracy is: 80.2 %
# Epoch [30/50], Step [100/245], Loss: 0.0199
# Epoch [30/50], Step [200/245], Loss: 0.0573
# Validation accuracy is: 80.2 %
# Epoch [31/50], Step [100/245], Loss: 0.0210
# Epoch [31/50], Step [200/245], Loss: 0.0337
# Validation accuracy is: 78.8 %
# Epoch [32/50], Step [100/245], Loss: 0.0179
# Epoch [32/50], Step [200/245], Loss: 0.0255
# Validation accuracy is: 80.2 %
# Epoch [33/50], Step [100/245], Loss: 0.0371
# Epoch [33/50], Step [200/245], Loss: 0.0311
# Validation accuracy is: 78.5 %
# Epoch [34/50], Step [100/245], Loss: 0.0175
# Epoch [34/50], Step [200/245], Loss: 0.0212
# Validation accuracy is: 79.9 %
# Epoch [35/50], Step [100/245], Loss: 0.0168
# Epoch [35/50], Step [200/245], Loss: 0.0316
# Validation accuracy is: 79.8 %
# Epoch [36/50], Step [100/245], Loss: 0.0208
# Epoch [36/50], Step [200/245], Loss: 0.0322
# Validation accuracy is: 80.0 %
# Epoch [37/50], Step [100/245], Loss: 0.0231
# Epoch [37/50], Step [200/245], Loss: 0.0258
# Validation accuracy is: 79.0 %
# Epoch [38/50], Step [100/245], Loss: 0.0177
# Epoch [38/50], Step [200/245], Loss: 0.0213
# Validation accuracy is: 80.8 %
# Epoch [39/50], Step [100/245], Loss: 0.0225
# Epoch [39/50], Step [200/245], Loss: 0.0256
# Validation accuracy is: 78.6 %
# Epoch [40/50], Step [100/245], Loss: 0.0220
# Epoch [40/50], Step [200/245], Loss: 0.0232
# Validation accuracy is: 79.3 %
# Epoch [41/50], Step [100/245], Loss: 0.0251
# Epoch [41/50], Step [200/245], Loss: 0.0257
# Validation accuracy is: 80.4 %
# Epoch [42/50], Step [100/245], Loss: 0.0144
# Epoch [42/50], Step [200/245], Loss: 0.0245
# Validation accuracy is: 79.4 %
# Epoch [43/50], Step [100/245], Loss: 0.0142
# Epoch [43/50], Step [200/245], Loss: 0.0247
# Validation accuracy is: 80.6 %
# Epoch [44/50], Step [100/245], Loss: 0.0121
# Epoch [44/50], Step [200/245], Loss: 0.0208
# Validation accuracy is: 80.5 %
# Epoch [45/50], Step [100/245], Loss: 0.0136
# Epoch [45/50], Step [200/245], Loss: 0.0253
# Validation accuracy is: 80.2 %
# Epoch [46/50], Step [100/245], Loss: 0.0161
# Epoch [46/50], Step [200/245], Loss: 0.0262
# Validation accuracy is: 79.9 %
# Epoch [47/50], Step [100/245], Loss: 0.0201
# Epoch [47/50], Step [200/245], Loss: 0.0192
# Validation accuracy is: 79.6 %
# Epoch [48/50], Step [100/245], Loss: 0.0108
# Epoch [48/50], Step [200/245], Loss: 0.0212
# Validation accuracy is: 80.7 %
# Epoch [49/50], Step [100/245], Loss: 0.0145
# Epoch [49/50], Step [200/245], Loss: 0.0149
# Validation accuracy is: 80.0 %
# Epoch [50/50], Step [100/245], Loss: 0.0179
# Epoch [50/50], Step [200/245], Loss: 0.0148
# Validation accuracy is: 80.1 %
# Accuracy of the network on the 1000 test images: 78.7 %
